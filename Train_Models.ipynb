# %% [markdown]
# # Index
# 1. [Loading Spectrogram Dataset](#1-loading-spetrogram-dataset-into-pytorch)
# 2. [Train And Test Functions](#2-train-and-test-functions)
# 3. [Models](#3-models)
#     * 3.1 [Custom Model Training](#31-custom-model-2d-cnn)
#     * 3.2 [ResNet18 Training](#32-resnet18-training)
#     * 3.3 [ViT Training](#33-vit-training)

# %% [markdown]
# ## 1. Loading spetrogram dataset into pytorch

# %%
# Load the Drive helper and mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd  /content/drive/'MyDrive'/CV/'CV Project'/'Computer-Vision-Project'/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CV/CV Project/Computer-Vision-Project

# %%
import random
import os
from os.path import splitext
import csv
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import pandas as pd
from sklearn.model_selection import train_test_split
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
from torchvision import transforms
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim import lr_scheduler

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print('device: ', device)
# Out:
# device:  cuda

# %% [markdown]
# ### Peeking into the labels data frame

# %%
INPUT_FOLDER = f"{os.getcwd()}/input"
OUTPUT_FOLDER = f"{os.getcwd()}/output_grayscale"

# %%
SPECTROGRAMS_FOLDER = f"{OUTPUT_FOLDER}/spectrograms"
data_frame = pd.read_csv(f"{OUTPUT_FOLDER}/labels.csv")

print(data_frame.head(), '\n')
print(data_frame['label'].value_counts().rename(index={0: 'No gun/Fake gun (0)', 1: 'Real gun (1)'}))
# Out:
#                                      file_name  label
# 0          southcentre_mall_window=1_gun=0.png      0
# 1   southcentre_mall_window=1_vol=8%_gun=1.png      1
# 2  southcentre_mall_window=1_vol=35%_gun=1.png      1
# 3  southcentre_mall_window=1_vol=70%_gun=1.png      1
# 4          southcentre_mall_window=2_gun=0.png      0
#
# label
# Real gun (1)           6978
# No gun/Fake gun (0)    4515
# Name: count, dtype: int64

# %% [markdown]
# ### Creating a custom dataset for the train_loader and test_loader

# %%
class CustomDataset(Dataset):
  def __init__(self, data_frame=None, transform=None):
    self.data_frame = data_frame
    self.transform = transform

  def __len__(self):
    return len(self.data_frame)

  def __getitem__(self, idx):
    img_name = self.data_frame.iloc[idx, 0]
    image = Image.open(f'{SPECTROGRAMS_FOLDER}/{img_name}').convert('RGB')
    label = int(self.data_frame.iloc[idx, 1])

    if self.transform:
        image = self.transform(image)

    return image, label

"""
Resize the image to standard size, most pretrained models use 224x224.
If we also use this resolution we can experiment with the built-in pretrained models from torchvision.
"""
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

whole_dataset = CustomDataset(data_frame=data_frame, transform=transform)

# Split the dataset into training and testing sets
train_dataset, test_dataset = train_test_split(whole_dataset, test_size=0.2, random_state=42)

# Create DataLoader instances for training and testing sets
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# ### Viridis images

# %%
torch.save(train_loader, 'train_loader.pth')

# %%
torch.save(test_loader, 'test_loader.pth')

# %%
train_loader = torch.load('train_loader.pth')
test_loader = torch.load('test_loader.pth')

# %% [markdown]
# ### Grayscale images

# %%
torch.save(train_loader, 'train_loader_grayscale.pth')

# %%
torch.save(test_loader, 'test_loader_grayscale.pth')

# %%
train_loader = torch.load('train_loader_grayscale.pth')
test_loader = torch.load('test_loader_grayscale.pth')

# %% [markdown]
# ### Looking into the dataloaders exactly as pytorch will receive them:

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)

# plot images and labels with no padding
fig = plt.figure(figsize=(16, 16))
for idx in np.arange(64):
  ax = fig.add_subplot(8, 8, idx+1, xticks=[], yticks=[])
  plt.imshow(np.transpose(images[idx], (1, 2, 0)))
  ax.set_title(f'{"gun (1)" if labels[idx] == 1 else "No gun (0)"}')

# %% [markdown]
# ## 2. Train and test functions

# %%
def train(model, optimizer, train_loader, epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
      data = data.to(device)
      target = target.to(device)
      target = target.view(target.shape[0], 1).float()

      optimizer.zero_grad()
      output = model(data)
      loss = F.binary_cross_entropy_with_logits(output, target).to(device)
      loss.backward()
      optimizer.step()
      if batch_idx % 25 == 0:
        print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
            epoch, batch_idx * len(data), len(train_loader.dataset),
            100. * batch_idx / len(train_loader), loss.item()))

def validation(model, test_loader):
    model.eval()
    validation_loss = 0
    correct = 0
    for data, target in test_loader:
      data = data.to(device)
      target = target.to(device)
      target = target.view(target.shape[0], 1).float()
    
      output = model(data)
      validation_loss += F.binary_cross_entropy_with_logits(output, target, reduction="sum").to(device).item() # sum up batch loss
      output = torch.sigmoid(output)
      pred = (target.eq((output>0.5).to(dtype=torch.long)).cpu().sum()) # get the index of the max log-probability
      correct += pred
    
    validation_loss /= len(test_loader.dataset)
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        validation_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

    return 100. * correct / len(test_loader.dataset)

def plot_accuracy(num_epochs, acc_perc_list, filename="plot.png"):
  plt.plot(range(num_epochs+1), acc_perc_list)
  plt.xlim([0,num_epochs+1])
  plt.ylim([50,100])
  plt.xticks([0, 5, 15, 20])
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy %')
  plt.savefig(filename)
  plt.show();

def run(model, optimizer, scheduler, train_loader, test_loader, num_epochs):
  acc_perc_list = []
  acc_perc = validation(model, test_loader)
  acc_perc_list.append(acc_perc)

  for epoch in range(1, num_epochs + 1):
      train(model, optimizer, train_loader, epoch)
      scheduler.step()
      acc_perc = validation(model, test_loader)
      acc_perc_list.append(acc_perc)

  return acc_perc_list
  # plot_accuracy(num_epochs, acc_perc_list)

# %% [markdown]
# ## 3. Models

# %% [markdown]
# ### 3.1. Custom Model: 2D CNN

# %%
class CustomNet(nn.Module):
    def __init__(self):
      super(CustomNet, self).__init__()
      self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
      self.bn2d1 = nn.BatchNorm2d(64, affine=True)
      self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
      self.bn2d2 = nn.BatchNorm2d(128, affine=True)
      self.fc1 = nn.Linear(56*56*128, 512)
#       self.fc1_5 = nn.Linear(256, 128)
      self.dropout = nn.Dropout()
      self.fc2 = nn.Linear(512, 1)

    def forward(self, x):
      x = F.relu(self.conv1(x))
      x = F.max_pool2d(x, 2)
      x = self.bn2d1(x)

      x = F.relu(self.conv2(x))
      x = F.max_pool2d(x, 2)
      x = self.bn2d2(x)

      x = x.view(x.size(0), -1)
      x = F.relu(self.fc1(x))
#       x = F.relu(self.fc1_5(x))
      x = self.dropout(x)

      x = self.fc2(x)

      return x

model_1 = CustomNet()
model_1 = model_1.to(device)

optimizer = optim.Adam(model_1.parameters(), lr=1e-5, weight_decay=1e-5)
# scheduler = lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer, 1, 2)


num_epochs = 20

# %%
acc_perc_list = run(model_1, train_loader, test_loader, num_epochs)
# Out:
# Validation set: Average loss: 0.7028, Accuracy: 954/2307 (41%)
#
# Train Epoch: 1 [0/9225 (0%)]	Loss: 0.746688
# Train Epoch: 1 [1600/9225 (17%)]	Loss: 0.736200
# Train Epoch: 1 [3200/9225 (34%)]	Loss: 0.697963
# Train Epoch: 1 [4800/9225 (52%)]	Loss: 0.754591
# Train Epoch: 1 [6400/9225 (69%)]	Loss: 0.708748
# Train Epoch: 1 [8000/9225 (86%)]	Loss: 0.738370
#
# Validation set: Average loss: 0.7116, Accuracy: 1186/2307 (51%)
#
# Train Epoch: 2 [0/9225 (0%)]	Loss: 0.696435
# Train Epoch: 2 [1600/9225 (17%)]	Loss: 0.728616
# Train Epoch: 2 [3200/9225 (34%)]	Loss: 0.674147
# Train Epoch: 2 [4800/9225 (52%)]	Loss: 0.719584
# Train Epoch: 2 [6400/9225 (69%)]	Loss: 0.651702
# Train Epoch: 2 [8000/9225 (86%)]	Loss: 0.492173
#
# Validation set: Average loss: 0.6324, Accuracy: 1492/2307 (65%)
#
# Train Epoch: 3 [0/9225 (0%)]	Loss: 0.679070
# Train Epoch: 3 [1600/9225 (17%)]	Loss: 0.517936
# Train Epoch: 3 [3200/9225 (34%)]	Loss: 0.600748
# Train Epoch: 3 [4800/9225 (52%)]	Loss: 0.576582
# Train Epoch: 3 [6400/9225 (69%)]	Loss: 0.506230
# Train Epoch: 3 [8000/9225 (86%)]	Loss: 0.566283
#
# Validation set: Average loss: 0.5885, Accuracy: 1559/2307 (68%)
#
# Train Epoch: 4 [0/9225 (0%)]	Loss: 0.448711
# Train Epoch: 4 [1600/9225 (17%)]	Loss: 0.440789
# Train Epoch: 4 [3200/9225 (34%)]	Loss: 0.442159
# Train Epoch: 4 [4800/9225 (52%)]	Loss: 0.498453
# Train Epoch: 4 [6400/9225 (69%)]	Loss: 0.481377
# Train Epoch: 4 [8000/9225 (86%)]	Loss: 0.510679
#
# Validation set: Average loss: 0.5107, Accuracy: 1704/2307 (74%)
#
# Train Epoch: 5 [0/9225 (0%)]	Loss: 0.429554
# Train Epoch: 5 [1600/9225 (17%)]	Loss: 0.338861
# Train Epoch: 5 [3200/9225 (34%)]	Loss: 0.455470
# Train Epoch: 5 [4800/9225 (52%)]	Loss: 0.409466
# Train Epoch: 5 [6400/9225 (69%)]	Loss: 0.431636
# Train Epoch: 5 [8000/9225 (86%)]	Loss: 0.413527
#
# Validation set: Average loss: 0.7520, Accuracy: 1408/2307 (61%)
#
# Train Epoch: 6 [0/9225 (0%)]	Loss: 0.320413
# Train Epoch: 6 [1600/9225 (17%)]	Loss: 0.330274
# Train Epoch: 6 [3200/9225 (34%)]	Loss: 0.357841
# Train Epoch: 6 [4800/9225 (52%)]	Loss: 0.305098
# Train Epoch: 6 [6400/9225 (69%)]	Loss: 0.347890
# Train Epoch: 6 [8000/9225 (86%)]	Loss: 0.390950
#
# Validation set: Average loss: 0.5185, Accuracy: 1743/2307 (76%)
#
# Train Epoch: 7 [0/9225 (0%)]	Loss: 0.312519
# Train Epoch: 7 [1600/9225 (17%)]	Loss: 0.336832
# Train Epoch: 7 [3200/9225 (34%)]	Loss: 0.360472
# Train Epoch: 7 [4800/9225 (52%)]	Loss: 0.267797
# Train Epoch: 7 [6400/9225 (69%)]	Loss: 0.332544
# Train Epoch: 7 [8000/9225 (86%)]	Loss: 0.324993
#
# Validation set: Average loss: 0.5142, Accuracy: 1659/2307 (72%)
#
# Train Epoch: 8 [0/9225 (0%)]	Loss: 0.300496
# Train Epoch: 8 [1600/9225 (17%)]	Loss: 0.338065
# Train Epoch: 8 [3200/9225 (34%)]	Loss: 0.303922
# Train Epoch: 8 [4800/9225 (52%)]	Loss: 0.329450
# Train Epoch: 8 [6400/9225 (69%)]	Loss: 0.269831
# Train Epoch: 8 [8000/9225 (86%)]	Loss: 0.337098
#
# Validation set: Average loss: 0.4985, Accuracy: 1746/2307 (76%)
#
# Train Epoch: 9 [0/9225 (0%)]	Loss: 0.340332
# Train Epoch: 9 [1600/9225 (17%)]	Loss: 0.293946
# Train Epoch: 9 [3200/9225 (34%)]	Loss: 0.340936
# Train Epoch: 9 [4800/9225 (52%)]	Loss: 0.289115
# Train Epoch: 9 [6400/9225 (69%)]	Loss: 0.281914
# Train Epoch: 9 [8000/9225 (86%)]	Loss: 0.316479
#
# Validation set: Average loss: 0.5004, Accuracy: 1680/2307 (73%)
#
# Train Epoch: 10 [0/9225 (0%)]	Loss: 0.310240
# Train Epoch: 10 [1600/9225 (17%)]	Loss: 0.234669
# Train Epoch: 10 [3200/9225 (34%)]	Loss: 0.339444
# Train Epoch: 10 [4800/9225 (52%)]	Loss: 0.274614
# Train Epoch: 10 [6400/9225 (69%)]	Loss: 0.260872
# Train Epoch: 10 [8000/9225 (86%)]	Loss: 0.294953
#
# Validation set: Average loss: 0.6262, Accuracy: 1556/2307 (67%)
#
# Train Epoch: 11 [0/9225 (0%)]	Loss: 0.265728
# Train Epoch: 11 [1600/9225 (17%)]	Loss: 0.232395
# Train Epoch: 11 [3200/9225 (34%)]	Loss: 0.278397
# Train Epoch: 11 [4800/9225 (52%)]	Loss: 0.335082
# Train Epoch: 11 [6400/9225 (69%)]	Loss: 0.265455
# Train Epoch: 11 [8000/9225 (86%)]	Loss: 0.258837
#
# Validation set: Average loss: 0.4921, Accuracy: 1698/2307 (74%)
#
# Train Epoch: 12 [0/9225 (0%)]	Loss: 0.367652
# Train Epoch: 12 [1600/9225 (17%)]	Loss: 0.318715
# Train Epoch: 12 [3200/9225 (34%)]	Loss: 0.258482
# Train Epoch: 12 [4800/9225 (52%)]	Loss: 0.273915
# Train Epoch: 12 [6400/9225 (69%)]	Loss: 0.275079
# Train Epoch: 12 [8000/9225 (86%)]	Loss: 0.335378
#
# Validation set: Average loss: 0.4956, Accuracy: 1709/2307 (74%)
#
# Train Epoch: 13 [0/9225 (0%)]	Loss: 0.376764
# Train Epoch: 13 [1600/9225 (17%)]	Loss: 0.319337
# Train Epoch: 13 [3200/9225 (34%)]	Loss: 0.307600
# Train Epoch: 13 [4800/9225 (52%)]	Loss: 0.221024
# Train Epoch: 13 [6400/9225 (69%)]	Loss: 0.271260
# Train Epoch: 13 [8000/9225 (86%)]	Loss: 0.233650
#
# Validation set: Average loss: 0.5042, Accuracy: 1669/2307 (72%)
#
# Train Epoch: 14 [0/9225 (0%)]	Loss: 0.279063
# Train Epoch: 14 [1600/9225 (17%)]	Loss: 0.341500
# Train Epoch: 14 [3200/9225 (34%)]	Loss: 0.299803
# Train Epoch: 14 [4800/9225 (52%)]	Loss: 0.289562
# Train Epoch: 14 [6400/9225 (69%)]	Loss: 0.292600
# Train Epoch: 14 [8000/9225 (86%)]	Loss: 0.260971
#
# Validation set: Average loss: 0.5014, Accuracy: 1695/2307 (73%)
#
# Train Epoch: 15 [0/9225 (0%)]	Loss: 0.253346
# Train Epoch: 15 [1600/9225 (17%)]	Loss: 0.218163
# Train Epoch: 15 [3200/9225 (34%)]	Loss: 0.276719
# Train Epoch: 15 [4800/9225 (52%)]	Loss: 0.277126
# Train Epoch: 15 [6400/9225 (69%)]	Loss: 0.396322
# Train Epoch: 15 [8000/9225 (86%)]	Loss: 0.263709
#
# Validation set: Average loss: 0.4955, Accuracy: 1706/2307 (74%)
#
# Train Epoch: 16 [0/9225 (0%)]	Loss: 0.279023
# Train Epoch: 16 [1600/9225 (17%)]	Loss: 0.271707
# Train Epoch: 16 [3200/9225 (34%)]	Loss: 0.322772
# Train Epoch: 16 [4800/9225 (52%)]	Loss: 0.302953
# Train Epoch: 16 [6400/9225 (69%)]	Loss: 0.266326
# Train Epoch: 16 [8000/9225 (86%)]	Loss: 0.255287
#
# Validation set: Average loss: 0.5018, Accuracy: 1663/2307 (72%)
#
# Train Epoch: 17 [0/9225 (0%)]	Loss: 0.235057
# Train Epoch: 17 [1600/9225 (17%)]	Loss: 0.229587
# Train Epoch: 17 [3200/9225 (34%)]	Loss: 0.288101
# Train Epoch: 17 [4800/9225 (52%)]	Loss: 0.258704
# Train Epoch: 17 [6400/9225 (69%)]	Loss: 0.283297
# Train Epoch: 17 [8000/9225 (86%)]	Loss: 0.295081
#
# Validation set: Average loss: 0.4957, Accuracy: 1678/2307 (73%)
#
# Train Epoch: 18 [0/9225 (0%)]	Loss: 0.278287
# Train Epoch: 18 [1600/9225 (17%)]	Loss: 0.221800
# Train Epoch: 18 [3200/9225 (34%)]	Loss: 0.296343
# Train Epoch: 18 [4800/9225 (52%)]	Loss: 0.279030
# Train Epoch: 18 [6400/9225 (69%)]	Loss: 0.302945
# Train Epoch: 18 [8000/9225 (86%)]	Loss: 0.266630
#
# Validation set: Average loss: 0.4975, Accuracy: 1704/2307 (74%)
#
# Train Epoch: 19 [0/9225 (0%)]	Loss: 0.250443
# Train Epoch: 19 [1600/9225 (17%)]	Loss: 0.271748
# Train Epoch: 19 [3200/9225 (34%)]	Loss: 0.262524
# Train Epoch: 19 [4800/9225 (52%)]	Loss: 0.264033
# Train Epoch: 19 [6400/9225 (69%)]	Loss: 0.240655
# Train Epoch: 19 [8000/9225 (86%)]	Loss: 0.284876
#
# Validation set: Average loss: 0.5009, Accuracy: 1681/2307 (73%)
#
# Train Epoch: 20 [0/9225 (0%)]	Loss: 0.244401
# Train Epoch: 20 [1600/9225 (17%)]	Loss: 0.314334
# Train Epoch: 20 [3200/9225 (34%)]	Loss: 0.305515
# Train Epoch: 20 [4800/9225 (52%)]	Loss: 0.321361
# Train Epoch: 20 [6400/9225 (69%)]	Loss: 0.371081
# Train Epoch: 20 [8000/9225 (86%)]	Loss: 0.298142
#
# Validation set: Average loss: 0.4990, Accuracy: 1681/2307 (73%)

# %%
[float(x) for x in acc_perc_list]
# Out:
# [41.3524055480957,
#  51.408756256103516,
#  64.67273712158203,
#  67.57694244384766,
#  73.8621597290039,
#  61.03164291381836,
#  75.55266571044922,
#  71.91157531738281,
#  75.68270111083984,
#  72.82184600830078,
#  67.4468994140625,
#  73.60208129882812,
#  74.07888793945312,
#  72.34503936767578,
#  73.47203826904297,
#  73.9488525390625,
#  72.0849609375,
#  72.73515319824219,
#  73.8621597290039,
#  72.86519622802734,
#  72.86519622802734]

# %% [markdown]
# ### 3.2. ResNet18 Training

# %%
from torchvision.models import ResNet18_Weights

model_2 = models.resnet18(weights=ResNet18_Weights.DEFAULT)

num_features = model_2.fc.in_features
model_2.fc = nn.Linear(num_features, 1)

for param in model_2.parameters():
    param.requires_grad = False

# Unfreeze the final layer
for param in model_2.fc.parameters():
    param.requires_grad = True

model_2 = model_2.to(device)

optimizer = optim.Adam(model_2.fc.parameters(), lr=1e-3, weight_decay=1e-4)

num_epochs = 20

# %%
acc_perc_list = run(model_2, train_loader, test_loader, num_epochs)
# Out:
# Validation set: Average loss: 0.6969, Accuracy: 1350/2307 (59%)
#
# Train Epoch: 1 [0/9225 (0%)]	Loss: 0.747262
# Train Epoch: 1 [1600/9225 (17%)]	Loss: 0.685120
# Train Epoch: 1 [3200/9225 (34%)]	Loss: 0.673080
# Train Epoch: 1 [4800/9225 (52%)]	Loss: 0.604822
# Train Epoch: 1 [6400/9225 (69%)]	Loss: 0.705280
# Train Epoch: 1 [8000/9225 (86%)]	Loss: 0.613612
#
# Validation set: Average loss: 0.5859, Accuracy: 1530/2307 (66%)
#
# Train Epoch: 2 [0/9225 (0%)]	Loss: 0.592733
# Train Epoch: 2 [1600/9225 (17%)]	Loss: 0.564733
# Train Epoch: 2 [3200/9225 (34%)]	Loss: 0.532867
# Train Epoch: 2 [4800/9225 (52%)]	Loss: 0.590503
# Train Epoch: 2 [6400/9225 (69%)]	Loss: 0.591516
# Train Epoch: 2 [8000/9225 (86%)]	Loss: 0.559415
#
# Validation set: Average loss: 0.5507, Accuracy: 1651/2307 (72%)
#
# Train Epoch: 3 [0/9225 (0%)]	Loss: 0.425539
# Train Epoch: 3 [1600/9225 (17%)]	Loss: 0.570886
# Train Epoch: 3 [3200/9225 (34%)]	Loss: 0.517741
# Train Epoch: 3 [4800/9225 (52%)]	Loss: 0.577782
# Train Epoch: 3 [6400/9225 (69%)]	Loss: 0.553732
# Train Epoch: 3 [8000/9225 (86%)]	Loss: 0.534912
#
# Validation set: Average loss: 0.5388, Accuracy: 1684/2307 (73%)
#
# Train Epoch: 4 [0/9225 (0%)]	Loss: 0.527378
# Train Epoch: 4 [1600/9225 (17%)]	Loss: 0.649551
# Train Epoch: 4 [3200/9225 (34%)]	Loss: 0.449983
# Train Epoch: 4 [4800/9225 (52%)]	Loss: 0.573933
# Train Epoch: 4 [6400/9225 (69%)]	Loss: 0.512938
# Train Epoch: 4 [8000/9225 (86%)]	Loss: 0.600851
#
# Validation set: Average loss: 0.5302, Accuracy: 1681/2307 (73%)
#
# Train Epoch: 5 [0/9225 (0%)]	Loss: 0.569244
# Train Epoch: 5 [1600/9225 (17%)]	Loss: 0.519179
# Train Epoch: 5 [3200/9225 (34%)]	Loss: 0.559702
# Train Epoch: 5 [4800/9225 (52%)]	Loss: 0.527081
# Train Epoch: 5 [6400/9225 (69%)]	Loss: 0.484320
# Train Epoch: 5 [8000/9225 (86%)]	Loss: 0.516060
#
# Validation set: Average loss: 0.5237, Accuracy: 1704/2307 (74%)
#
# Train Epoch: 6 [0/9225 (0%)]	Loss: 0.523766
# Train Epoch: 6 [1600/9225 (17%)]	Loss: 0.529987
# Train Epoch: 6 [3200/9225 (34%)]	Loss: 0.477821
# Train Epoch: 6 [4800/9225 (52%)]	Loss: 0.474272
# Train Epoch: 6 [6400/9225 (69%)]	Loss: 0.702345
# Train Epoch: 6 [8000/9225 (86%)]	Loss: 0.488457
#
# Validation set: Average loss: 0.5220, Accuracy: 1707/2307 (74%)
#
# Train Epoch: 7 [0/9225 (0%)]	Loss: 0.573284
# Train Epoch: 7 [1600/9225 (17%)]	Loss: 0.587093
# Train Epoch: 7 [3200/9225 (34%)]	Loss: 0.490978
# Train Epoch: 7 [4800/9225 (52%)]	Loss: 0.468287
# Train Epoch: 7 [6400/9225 (69%)]	Loss: 0.512951
# Train Epoch: 7 [8000/9225 (86%)]	Loss: 0.486229
#
# Validation set: Average loss: 0.5171, Accuracy: 1690/2307 (73%)
#
# Train Epoch: 8 [0/9225 (0%)]	Loss: 0.497930
# Train Epoch: 8 [1600/9225 (17%)]	Loss: 0.527572
# Train Epoch: 8 [3200/9225 (34%)]	Loss: 0.481515
# Train Epoch: 8 [4800/9225 (52%)]	Loss: 0.517023
# Train Epoch: 8 [6400/9225 (69%)]	Loss: 0.540166
# Train Epoch: 8 [8000/9225 (86%)]	Loss: 0.461402
#
# Validation set: Average loss: 0.5137, Accuracy: 1695/2307 (73%)
#
# Train Epoch: 9 [0/9225 (0%)]	Loss: 0.473685
# Train Epoch: 9 [1600/9225 (17%)]	Loss: 0.569585
# Train Epoch: 9 [3200/9225 (34%)]	Loss: 0.527919
# Train Epoch: 9 [4800/9225 (52%)]	Loss: 0.557770
# Train Epoch: 9 [6400/9225 (69%)]	Loss: 0.601659
# Train Epoch: 9 [8000/9225 (86%)]	Loss: 0.546490
#
# Validation set: Average loss: 0.5137, Accuracy: 1699/2307 (74%)
#
# Train Epoch: 10 [0/9225 (0%)]	Loss: 0.459998
# Train Epoch: 10 [1600/9225 (17%)]	Loss: 0.487551
# Train Epoch: 10 [3200/9225 (34%)]	Loss: 0.508554
# Train Epoch: 10 [4800/9225 (52%)]	Loss: 0.480032
# Train Epoch: 10 [6400/9225 (69%)]	Loss: 0.575155
# Train Epoch: 10 [8000/9225 (86%)]	Loss: 0.463339
#
# Validation set: Average loss: 0.5192, Accuracy: 1674/2307 (73%)
#
# Train Epoch: 11 [0/9225 (0%)]	Loss: 0.484611
# Train Epoch: 11 [1600/9225 (17%)]	Loss: 0.529518
# Train Epoch: 11 [3200/9225 (34%)]	Loss: 0.430675
# Train Epoch: 11 [4800/9225 (52%)]	Loss: 0.561792
# Train Epoch: 11 [6400/9225 (69%)]	Loss: 0.425298
# Train Epoch: 11 [8000/9225 (86%)]	Loss: 0.499763
#
# Validation set: Average loss: 0.5173, Accuracy: 1711/2307 (74%)
#
# Train Epoch: 12 [0/9225 (0%)]	Loss: 0.550554
# Train Epoch: 12 [1600/9225 (17%)]	Loss: 0.582961
# Train Epoch: 12 [3200/9225 (34%)]	Loss: 0.539894
# Train Epoch: 12 [4800/9225 (52%)]	Loss: 0.632584
# Train Epoch: 12 [6400/9225 (69%)]	Loss: 0.388719
# Train Epoch: 12 [8000/9225 (86%)]	Loss: 0.499065
#
# Validation set: Average loss: 0.5134, Accuracy: 1700/2307 (74%)
#
# Train Epoch: 13 [0/9225 (0%)]	Loss: 0.547880
# Train Epoch: 13 [1600/9225 (17%)]	Loss: 0.459716
# Train Epoch: 13 [3200/9225 (34%)]	Loss: 0.520565
# Train Epoch: 13 [4800/9225 (52%)]	Loss: 0.477737
# Train Epoch: 13 [6400/9225 (69%)]	Loss: 0.555431
# Train Epoch: 13 [8000/9225 (86%)]	Loss: 0.562855
#
# Validation set: Average loss: 0.5113, Accuracy: 1695/2307 (73%)
#
# Train Epoch: 14 [0/9225 (0%)]	Loss: 0.479255
# Train Epoch: 14 [1600/9225 (17%)]	Loss: 0.447207
# Train Epoch: 14 [3200/9225 (34%)]	Loss: 0.523588
# Train Epoch: 14 [4800/9225 (52%)]	Loss: 0.510795
# Train Epoch: 14 [6400/9225 (69%)]	Loss: 0.431599
# Train Epoch: 14 [8000/9225 (86%)]	Loss: 0.502019
#
# Validation set: Average loss: 0.5089, Accuracy: 1717/2307 (74%)
#
# Train Epoch: 15 [0/9225 (0%)]	Loss: 0.449368
# Train Epoch: 15 [1600/9225 (17%)]	Loss: 0.445242
# Train Epoch: 15 [3200/9225 (34%)]	Loss: 0.463305
# Train Epoch: 15 [4800/9225 (52%)]	Loss: 0.477482
# Train Epoch: 15 [6400/9225 (69%)]	Loss: 0.444408
# Train Epoch: 15 [8000/9225 (86%)]	Loss: 0.438022
#
# Validation set: Average loss: 0.5130, Accuracy: 1712/2307 (74%)
#
# Train Epoch: 16 [0/9225 (0%)]	Loss: 0.500687
# Train Epoch: 16 [1600/9225 (17%)]	Loss: 0.400987
# Train Epoch: 16 [3200/9225 (34%)]	Loss: 0.491871
# Train Epoch: 16 [4800/9225 (52%)]	Loss: 0.526590
# Train Epoch: 16 [6400/9225 (69%)]	Loss: 0.506263
# Train Epoch: 16 [8000/9225 (86%)]	Loss: 0.509052
#
# Validation set: Average loss: 0.5083, Accuracy: 1710/2307 (74%)
#
# Train Epoch: 17 [0/9225 (0%)]	Loss: 0.475551
# Train Epoch: 17 [1600/9225 (17%)]	Loss: 0.560971
# Train Epoch: 17 [3200/9225 (34%)]	Loss: 0.522432
# Train Epoch: 17 [4800/9225 (52%)]	Loss: 0.538760
# Train Epoch: 17 [6400/9225 (69%)]	Loss: 0.450810
# Train Epoch: 17 [8000/9225 (86%)]	Loss: 0.491100
#
# Validation set: Average loss: 0.5320, Accuracy: 1671/2307 (72%)
#
# Train Epoch: 18 [0/9225 (0%)]	Loss: 0.495662
# Train Epoch: 18 [1600/9225 (17%)]	Loss: 0.428233
# Train Epoch: 18 [3200/9225 (34%)]	Loss: 0.589449
# Train Epoch: 18 [4800/9225 (52%)]	Loss: 0.396424
# Train Epoch: 18 [6400/9225 (69%)]	Loss: 0.512596
# Train Epoch: 18 [8000/9225 (86%)]	Loss: 0.516201
#
# Validation set: Average loss: 0.5127, Accuracy: 1686/2307 (73%)
#
# Train Epoch: 19 [0/9225 (0%)]	Loss: 0.624236
# Train Epoch: 19 [1600/9225 (17%)]	Loss: 0.560773
# Train Epoch: 19 [3200/9225 (34%)]	Loss: 0.485728
# Train Epoch: 19 [4800/9225 (52%)]	Loss: 0.538918
# Train Epoch: 19 [6400/9225 (69%)]	Loss: 0.494929
# Train Epoch: 19 [8000/9225 (86%)]	Loss: 0.453029
#
# Validation set: Average loss: 0.5086, Accuracy: 1703/2307 (74%)
#
# Train Epoch: 20 [0/9225 (0%)]	Loss: 0.453810
# Train Epoch: 20 [1600/9225 (17%)]	Loss: 0.448179
# Train Epoch: 20 [3200/9225 (34%)]	Loss: 0.462248
# Train Epoch: 20 [4800/9225 (52%)]	Loss: 0.584509
# Train Epoch: 20 [6400/9225 (69%)]	Loss: 0.595919
# Train Epoch: 20 [8000/9225 (86%)]	Loss: 0.444791
#
# Validation set: Average loss: 0.5077, Accuracy: 1719/2307 (75%)

# %%
plot_accuracy(num_epochs, acc_perc_list)

# %% [markdown]
# ### 3.3. ViT Training

# %%
from torchvision.models import vit_b_16, ViT_B_16_Weights

model_3 = vit_b_16(weights=ViT_B_16_Weights.DEFAULT)
model_3.heads.head = nn.Linear(768,1,bias=True)
model_3 = model_3.to(device)

optimizer = torch.optim.SGD(model_3.parameters(), lr=1e-4, momentum=0.9)
scheduler = lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=1, T_mult=2, eta_min=1e-8)

num_epochs = 20

# %%
acc_perc_list = run(model_3, optimizer, scheduler, train_loader, test_loader, num_epochs)
# Out:
# Validation set: Average loss: 0.7737, Accuracy: 960/2307 (42%)
#
# Train Epoch: 1 [0/9225 (0%)]	Loss: 0.853399
# Train Epoch: 1 [1600/9225 (17%)]	Loss: 0.626714
# Train Epoch: 1 [3200/9225 (34%)]	Loss: 0.661719
# Train Epoch: 1 [4800/9225 (52%)]	Loss: 0.607211
# Train Epoch: 1 [6400/9225 (69%)]	Loss: 0.577078
# Train Epoch: 1 [8000/9225 (86%)]	Loss: 0.622170
#
# Validation set: Average loss: 0.5838, Accuracy: 1588/2307 (69%)
#
# Train Epoch: 2 [0/9225 (0%)]	Loss: 0.618367
# Train Epoch: 2 [1600/9225 (17%)]	Loss: 0.584404
# Train Epoch: 2 [3200/9225 (34%)]	Loss: 0.491300
# Train Epoch: 2 [4800/9225 (52%)]	Loss: 0.582435
# Train Epoch: 2 [6400/9225 (69%)]	Loss: 0.515911
# Train Epoch: 2 [8000/9225 (86%)]	Loss: 0.505207
#
# Validation set: Average loss: 0.4805, Accuracy: 1751/2307 (76%)
#
# Train Epoch: 3 [0/9225 (0%)]	Loss: 0.432981
# Train Epoch: 3 [1600/9225 (17%)]	Loss: 0.449771
# Train Epoch: 3 [3200/9225 (34%)]	Loss: 0.515618
# Train Epoch: 3 [4800/9225 (52%)]	Loss: 0.457044
# Train Epoch: 3 [6400/9225 (69%)]	Loss: 0.444884
# Train Epoch: 3 [8000/9225 (86%)]	Loss: 0.527621
#
# Validation set: Average loss: 0.4428, Accuracy: 1795/2307 (78%)
#
# Train Epoch: 4 [0/9225 (0%)]	Loss: 0.461105
# Train Epoch: 4 [1600/9225 (17%)]	Loss: 0.393145
# Train Epoch: 4 [3200/9225 (34%)]	Loss: 0.354051
# Train Epoch: 4 [4800/9225 (52%)]	Loss: 0.426272
# Train Epoch: 4 [6400/9225 (69%)]	Loss: 0.335515
# Train Epoch: 4 [8000/9225 (86%)]	Loss: 0.416571
#
# Validation set: Average loss: 0.3985, Accuracy: 1889/2307 (82%)
#
# Train Epoch: 5 [0/9225 (0%)]	Loss: 0.332721
# Train Epoch: 5 [1600/9225 (17%)]	Loss: 0.288984
# Train Epoch: 5 [3200/9225 (34%)]	Loss: 0.394621
# Train Epoch: 5 [4800/9225 (52%)]	Loss: 0.321538
# Train Epoch: 5 [6400/9225 (69%)]	Loss: 0.334268
# Train Epoch: 5 [8000/9225 (86%)]	Loss: 0.388242
#
# Validation set: Average loss: 0.3597, Accuracy: 1937/2307 (84%)
#
# Train Epoch: 6 [0/9225 (0%)]	Loss: 0.351035
# Train Epoch: 6 [1600/9225 (17%)]	Loss: 0.345510
# Train Epoch: 6 [3200/9225 (34%)]	Loss: 0.261067
# Train Epoch: 6 [4800/9225 (52%)]	Loss: 0.425095
# Train Epoch: 6 [6400/9225 (69%)]	Loss: 0.299033
# Train Epoch: 6 [8000/9225 (86%)]	Loss: 0.330495
#
# Validation set: Average loss: 0.3500, Accuracy: 1937/2307 (84%)
#
# Train Epoch: 7 [0/9225 (0%)]	Loss: 0.403190
# Train Epoch: 7 [1600/9225 (17%)]	Loss: 0.328497
# Train Epoch: 7 [3200/9225 (34%)]	Loss: 0.313806
# Train Epoch: 7 [4800/9225 (52%)]	Loss: 0.349596
# Train Epoch: 7 [6400/9225 (69%)]	Loss: 0.275332
# Train Epoch: 7 [8000/9225 (86%)]	Loss: 0.231338
#
# Validation set: Average loss: 0.3462, Accuracy: 1948/2307 (84%)
#
# Train Epoch: 8 [0/9225 (0%)]	Loss: 0.314699
# Train Epoch: 8 [1600/9225 (17%)]	Loss: 0.380802
# Train Epoch: 8 [3200/9225 (34%)]	Loss: 0.193276
# Train Epoch: 8 [4800/9225 (52%)]	Loss: 0.297277
# Train Epoch: 8 [6400/9225 (69%)]	Loss: 0.336537
# Train Epoch: 8 [8000/9225 (86%)]	Loss: 0.302815
#
# Validation set: Average loss: 0.3370, Accuracy: 1956/2307 (85%)
#
# Train Epoch: 9 [0/9225 (0%)]	Loss: 0.344139
# Train Epoch: 9 [1600/9225 (17%)]	Loss: 0.215907
# Train Epoch: 9 [3200/9225 (34%)]	Loss: 0.311178
# Train Epoch: 9 [4800/9225 (52%)]	Loss: 0.322050
# Train Epoch: 9 [6400/9225 (69%)]	Loss: 0.381232
# Train Epoch: 9 [8000/9225 (86%)]	Loss: 0.270939
#
# Validation set: Average loss: 0.3236, Accuracy: 1959/2307 (85%)
#
# Train Epoch: 10 [0/9225 (0%)]	Loss: 0.248812
# Train Epoch: 10 [1600/9225 (17%)]	Loss: 0.219798
# Train Epoch: 10 [3200/9225 (34%)]	Loss: 0.225806
# Train Epoch: 10 [4800/9225 (52%)]	Loss: 0.298980
# Train Epoch: 10 [6400/9225 (69%)]	Loss: 0.337110
# Train Epoch: 10 [8000/9225 (86%)]	Loss: 0.272475
#
# Validation set: Average loss: 0.3275, Accuracy: 1959/2307 (85%)
#
# Train Epoch: 11 [0/9225 (0%)]	Loss: 0.266930
# Train Epoch: 11 [1600/9225 (17%)]	Loss: 0.316898
# Train Epoch: 11 [3200/9225 (34%)]	Loss: 0.324902
# Train Epoch: 11 [4800/9225 (52%)]	Loss: 0.397722
# Train Epoch: 11 [6400/9225 (69%)]	Loss: 0.191885
# Train Epoch: 11 [8000/9225 (86%)]	Loss: 0.307094
#
# Validation set: Average loss: 0.3093, Accuracy: 1996/2307 (87%)
#
# Train Epoch: 12 [0/9225 (0%)]	Loss: 0.132947
# Train Epoch: 12 [1600/9225 (17%)]	Loss: 0.173246
# Train Epoch: 12 [3200/9225 (34%)]	Loss: 0.254182
# Train Epoch: 12 [4800/9225 (52%)]	Loss: 0.270097
# Train Epoch: 12 [6400/9225 (69%)]	Loss: 0.234973
# Train Epoch: 12 [8000/9225 (86%)]	Loss: 0.215682
#
# Validation set: Average loss: 0.3086, Accuracy: 1981/2307 (86%)
#
# Train Epoch: 13 [0/9225 (0%)]	Loss: 0.206376
# Train Epoch: 13 [1600/9225 (17%)]	Loss: 0.227086
# Train Epoch: 13 [3200/9225 (34%)]	Loss: 0.205116
# Train Epoch: 13 [4800/9225 (52%)]	Loss: 0.324778
# Train Epoch: 13 [6400/9225 (69%)]	Loss: 0.242458
# Train Epoch: 13 [8000/9225 (86%)]	Loss: 0.286099
#
# Validation set: Average loss: 0.3021, Accuracy: 1995/2307 (86%)
#
# Train Epoch: 14 [0/9225 (0%)]	Loss: 0.348114
# Train Epoch: 14 [1600/9225 (17%)]	Loss: 0.185199
# Train Epoch: 14 [3200/9225 (34%)]	Loss: 0.228174
# Train Epoch: 14 [4800/9225 (52%)]	Loss: 0.242557
# Train Epoch: 14 [6400/9225 (69%)]	Loss: 0.285744
# Train Epoch: 14 [8000/9225 (86%)]	Loss: 0.265200
#
# Validation set: Average loss: 0.3059, Accuracy: 1989/2307 (86%)
#
# Train Epoch: 15 [0/9225 (0%)]	Loss: 0.160961
# Train Epoch: 15 [1600/9225 (17%)]	Loss: 0.267038
# Train Epoch: 15 [3200/9225 (34%)]	Loss: 0.204725
# Train Epoch: 15 [4800/9225 (52%)]	Loss: 0.218410
# Train Epoch: 15 [6400/9225 (69%)]	Loss: 0.240901
# Train Epoch: 15 [8000/9225 (86%)]	Loss: 0.357058
#
# Validation set: Average loss: 0.3051, Accuracy: 1999/2307 (87%)
#
# Train Epoch: 16 [0/9225 (0%)]	Loss: 0.208866
# Train Epoch: 16 [1600/9225 (17%)]	Loss: 0.212741
# Train Epoch: 16 [3200/9225 (34%)]	Loss: 0.199891
# Train Epoch: 16 [4800/9225 (52%)]	Loss: 0.281997
# Train Epoch: 16 [6400/9225 (69%)]	Loss: 0.300950

# %%
[float(x) for x in acc_perc_list]
# Out:
# [57.824012756347656,
#  70.2210693359375,
#  76.46293640136719,
#  79.02037048339844,
#  82.18465423583984,
#  83.44169616699219,
#  84.2652816772461,
#  84.13523864746094,
#  84.1785888671875,
#  84.78543853759766,
#  85.82574462890625,
#  86.30255889892578,
#  86.38925170898438,
#  86.17251586914062,
#  85.9557876586914,
#  85.69570922851562,
#  86.21586608886719,
#  85.13220977783203,
#  86.17251586914062,
#  85.21890258789062,
#  86.73602294921875]
